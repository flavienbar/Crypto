# %% [markdown]
# # DATA INGESTION
# **Sources** : \
# Get sources from external folder
# - google trends
# - yahoo
# - glassnode
#
# **Goals** :
# - Database creation
# - Put data into the Raw folder

# %%
import pandas as pd
from datetime import date

# %% [markdown]
# ## Sources

# %% [markdown]
# ### Google Trends

# %%
gogole_df = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/google/google_trends/btc_googletrends_2021_10_21.parquet.gzip')
gogole_df
# Out:
#             bitcoin  btc  cryptocurrency  isPartial
# date
# 2014-08-31       55   16               1      False
# 2014-09-01       59   15               1      False
# 2014-09-02       50   13               1      False
# 2014-09-03       51   18               1      False
# 2014-09-04       48   18               1      False
# ...             ...  ...             ...        ...
# 2021-10-15        3    1               0      False
# 2021-10-16        2    0               0      False
# 2021-10-17        2    0               0      False
# 2021-10-18        2    0               0      False
# 2021-10-19      100   72              39      False
#
# [2623 rows x 4 columns]

# %%
google_db = google_df.loc['2014-09-17':].copy()
google_db
# Out:
#             bitcoin  btc  cryptocurrency  isPartial
# date
# 2014-09-17       44   15               1      False
# 2014-09-18       50   18               1      False
# 2014-09-19       56   19               0      False
# 2014-09-20       52   19               1      False
# 2014-09-21       59   17               1      False
# ...             ...  ...             ...        ...
# 2021-10-15        3    1               0      False
# 2021-10-16        2    0               0      False
# 2021-10-17        2    0               0      False
# 2021-10-18        2    0               0      False
# 2021-10-19      100   72              39      False
#
# [2606 rows x 4 columns]

# %%
#google_db.to_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/raw/btc_googletrends_{}.parquet.gzip'.format(date.today().strftime("%Y_%m_%d")), compression='gzip')

# %% [markdown]
# ### Yahoo

# %%
yahoo_df = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/yahoo/daily/usd/all_yahoo_2021_10_21.parquet.gzip')
yahoo_df
# Out:
#              VET-USD                                              \
#                 Open      High       Low     Close        Volume
# Date
# 1927-12-30       NaN       NaN       NaN       NaN           NaN
# 1928-01-03       NaN       NaN       NaN       NaN           NaN
# 1928-01-04       NaN       NaN       NaN       NaN           NaN
# 1928-01-05       NaN       NaN       NaN       NaN           NaN
# 1928-01-09       NaN       NaN       NaN       NaN           NaN
# ...              ...       ...       ...       ...           ...
# 2021-10-17  0.119825  0.127527  0.116873  0.122243  6.345386e+08
# 2021-10-18  0.122254  0.123747  0.116978  0.118551  4.218356e+08
# 2021-10-19  0.118551  0.119335  0.114771  0.116163  3.372777e+08
# 2021-10-20  0.116161  0.123003  0.115251  0.122075  4.134303e+08
# 2021-10-21  0.123163  0.135694  0.122209  0.132979  1.012209e+09
#
#                  BTC-USD                                            \
# ...

# %%
yahoo_db = yahoo_df.loc['2014-09-17':].copy()
yahoo_db
# Out:
#              VET-USD                                              \
#                 Open      High       Low     Close        Volume
# Date
# 2014-09-17       NaN       NaN       NaN       NaN           NaN
# 2014-09-18       NaN       NaN       NaN       NaN           NaN
# 2014-09-19       NaN       NaN       NaN       NaN           NaN
# 2014-09-20       NaN       NaN       NaN       NaN           NaN
# 2014-09-21       NaN       NaN       NaN       NaN           NaN
# ...              ...       ...       ...       ...           ...
# 2021-10-17  0.119825  0.127527  0.116873  0.122243  6.345386e+08
# 2021-10-18  0.122254  0.123747  0.116978  0.118551  4.218356e+08
# 2021-10-19  0.118551  0.119335  0.114771  0.116163  3.372777e+08
# 2021-10-20  0.116161  0.123003  0.115251  0.122075  4.134303e+08
# 2021-10-21  0.123163  0.135694  0.122209  0.132979  1.012209e+09
#
#                  BTC-USD                                            \
# ...

# %%
#yahoo_db.to_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/raw/all_yahoo_{}.parquet.gzip'.format(date.today().strftime("%Y_%m_%d")), compression='gzip')

# %% [markdown]
# ### Glassnode

# %%
from os import listdir

# %%
glass_files = [ 'adr_df_btc', 'fees_df', 'indicator_df1', 'indicator_df3', 'market_df', 'supply_df', 'transact_df']
glass_files

# %%
adr_df = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/adr_df_btc_2021_10_24.parquet.gzip')

fees_df = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/fees_df_2021_10_24.parquet.gzip')

indicator_df1 = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/indicator_df1_2021_10_24.parquet.gzip')

indicator_df3 = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/indicator_df3_2021_10_24.parquet.gzip')

market_df = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/market_df_2021_10_24.parquet.gzip')

supply_df = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/supply_df_2021_10_24.parquet.gzip')

transact_df = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/transact_df_2021_10_24.parquet.gzip')

# %%
glassnode_db = adr_df.join(fees_df).join(indicator_df1).join(indicator_df3).join(market_df, rsuffix='_mkt').join(supply_df).join(transact_df,  rsuffix='_transact')
glassnode_db
# Out:
#                 count  sending_count  receiving_count  active_count  \
# t
# 2009-01-03          1              0                0             0
# 2009-01-04          1              0                0             0
# 2009-01-05          1              0                0             0
# 2009-01-06          1              0                0             0
# 2009-01-07          1              0                0             0
# ...               ...            ...              ...           ...
# 2021-10-19  890556967         721691           743760       1077630
# 2021-10-20  891017464         594967           713145        975443
# 2021-10-21  891520431         760647           765433       1135695
# 2021-10-22  891969926         642110           693358        974151
# 2021-10-23  892350675         493467           597140        814845
#
#             new_non_zero_count  non_zero_count  min_point_zero_1_count  \
# t
# ...

# %%
#glassnode_db.to_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/raw/all_glassnode_{}.parquet.gzip'.format(date.today().strftime("%Y_%m_%d")), compression='gzip')
