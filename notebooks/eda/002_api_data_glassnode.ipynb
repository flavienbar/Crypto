# %% [markdown]
# # Glassnode

# %% [markdown]
# ## Datasets
# **Glassnode's sources** :
# -   Adress
# -   DeFi
# -   Derivatives
# -   Distribution
# -   Fees
# -   Market
# -   Mining
# -   Supply
# -   Transaction
#
# https://docs.glassnode.com/api

# %% [markdown]
# ### Data source loading

# %%
import pandas as pd

# %%
address = pd.read_parquet('/home/giujorge/datalake/lab/Crypto/crypto/data/external/glassnode/btc/adr_df_btc_2021_10_24.parquet.gzip')
address
# Out:
#                 count  sending_count  receiving_count  active_count  \
# t
# 2009-01-03          1              0                0             0
# 2009-01-04          1              0                0             0
# 2009-01-05          1              0                0             0
# 2009-01-06          1              0                0             0
# 2009-01-07          1              0                0             0
# ...               ...            ...              ...           ...
# 2021-10-19  890556967         721691           743760       1077630
# 2021-10-20  891017464         594967           713145        975443
# 2021-10-21  891520431         760647           765433       1135695
# 2021-10-22  891969926         642110           693358        974151
# 2021-10-23  892350675         493467           597140        814845
#
#             new_non_zero_count  non_zero_count  min_point_zero_1_count  \
# t
# ...

# %%
address  = adress.loc['2014-09-17':].copy()
# Out:
#                 count  sending_count  receiving_count  active_count  \
# t
# 2014-09-17   47335995         136567           162684        192638
# 2014-09-18   47444081         132846           164643        192303
# 2014-09-19   47538600         117648           142421        169742
# 2014-09-20   47624055         110874           139288        167810
# 2014-09-21   47692897          90710           182287        203096
# ...               ...            ...              ...           ...
# 2021-10-19  890556967         721691           743760       1077630
# 2021-10-20  891017464         594967           713145        975443
# 2021-10-21  891520431         760647           765433       1135695
# 2021-10-22  891969926         642110           693358        974151
# 2021-10-23  892350675         493467           597140        814845
#
#             new_non_zero_count  non_zero_count  min_point_zero_1_count  \
# t
# ...
